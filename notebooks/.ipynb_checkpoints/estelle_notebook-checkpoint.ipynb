# %% [markdown]
# # This is Estelle's notebook

# %% [markdown]
# ## Web scrapping to get the series symbol and names

# %%
import requests
from bs4 import BeautifulSoup
import httpx

# %%
url = 'https://cardmavin.com/pokemon/pokemon-card-set-symbols'

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
items = soup.find_all('tr')

# %%
dicty_full = {'name': [], 'link': []}

for item in items:
    if item.find('td', class_='column-3'):
        name = item.find('td', class_='column-1').find('a').text
        links = item.find('td', class_='column-3').find_all("img")
        
        if len(links) > 1:
            for i, link in enumerate(links):
                dicty_full['name'].append( f"{name}_{i}" )
                dicty_full['link'].append( link.attrs["data-src"] )
        elif len(links) == 1:
            dicty_full['name'].append( f"{name}" )
            dicty_full['link'].append( item.find('td', class_='column-3').find("img").attrs["data-src"] )

# %%
for i, thing in enumerate(dicty_full['name']):
    with open(f"../raw_data/SetSymbols/{dicty_full['name'][i]}.png", "wb") as file:
        image = httpx.get(dicty_full["link"][i])
        # Save the image binary data into the file
        file.write(image.content)
        print(f"Image {dicty_full['name'][i]} has been scraped")

print("Image saving is done")
# Out:
# Image Scarlet & Violet 151 has been scraped
# Image Obsidian Flames has been scraped
# Image Paldea Evolved has been scraped
# Image Scarlet & Violet has been scraped
# Image Crown Zenith has been scraped
# Image Silver Tempest has been scraped
# Image Lost Origin has been scraped
# Image Pokemon GO has been scraped
# Image Astral Radiance has been scraped
# Image Brilliant Stars has been scraped
# Image Fusion Strike has been scraped
# Image Celebrations has been scraped
# Image Celebrations Classic Collection has been scraped
# Image Evolving Skies has been scraped
# Image Chilling Reign has been scraped
# Image Battle Styles has been scraped
# Image Shining Fates has been scraped
# Image Vivid Voltage has been scraped
# Image Champion's Path has been scraped
# Image Darkness Ablaze has been scraped
# Image Rebel Clash has been scraped
# Image Sword & Shield has been scraped
# Image Cosmic Eclipse has been scraped
# Image Hidden Fates has been scraped
# Image Unified Minds has been scraped
# Image Unbroken Bonds has been scraped
# Image Detective Pikachu has been scraped
# Image Team Up has been scraped
# Image Lost Thunder has been scraped
# Image Dragon Majesty has been scraped
# Image Celestial Storm has been scraped
# Image Forbidden Light has been scraped
# Image Ultra Prism has been scraped
# Image Crimson Invasion has been scraped
# Image Shining Legends has been scraped
# Image Burning Shadows has been scraped
# Image Guardians Rising has been scraped
# Image Trainer Kit – Lycanroc & Alolan Raichu_0 has been scraped
# Image Trainer Kit – Lycanroc & Alolan Raichu_1 has been scraped
# Image Sun & Moon has been scraped
# Image Sun & Moon Promos has been scraped
# Image Evolutions has been scraped
# Image Steam Siege has been scraped
# Image Fates Collide has been scraped
# Image Trainer Kit – Pikachu Libre & Suicune_0 has been scraped
# Image Trainer Kit – Pikachu Libre & Suicune_1 has been scraped
# Image Generations has been scraped
# Image BREAKpoint has been scraped
# Image BREAKthrough has been scraped
# Image Ancient Origins has been scraped
# Image Roaring Skies has been scraped
# Image Trainer Kit – Latias & Latios_0 has been scraped
# Image Trainer Kit – Latias & Latios_1 has been scraped
# Image Double Crisis has been scraped
# Image Primal Clash has been scraped
# Image Trainer Kit – Bisharp & Wigglytuff_0 has been scraped
# Image Trainer Kit – Bisharp & Wigglytuff_1 has been scraped
# Image Phantom Forces has been scraped
# Image Furious Fists has been scraped
# Image Trainer Kit – Sylveon & Noivern_0 has been scraped
# Image Trainer Kit – Sylveon & Noivern_1 has been scraped
# Image Flashfire has been scraped
# Image XY has been scraped
# Image Kalos Starter Set has been scraped
# Image XY - Promos has been scraped
# Image Legendary Treasures has been scraped
# Image Plasma Blast has been scraped
# Image Plasma Freeze has been scraped
# Image Plasma Storm has been scraped
# Image Boundaries Crossed has been scraped
# Image Dragon Vault has been scraped
# Image Dragons Exalted has been scraped
# Image Dark Explorers has been scraped
# Image Next Destinies has been scraped
# Image Noble Victories has been scraped
# Image Trainer Kit – Excadrill & Zoroark_0 has been scraped
# Image Trainer Kit – Excadrill & Zoroark_1 has been scraped
# Image Emerging Powers has been scraped
# Image Black and White Base Set has been scraped
# Image Call of Legends has been scraped
# Image Triumphant has been scraped
# Image Undaunted has been scraped
# Image Unleashed has been scraped
# Image Trainer Kit – Gyarados & Raichu_0 has been scraped
# Image Trainer Kit – Gyarados & Raichu_1 has been scraped
# Image HeartGold and SoulSilver has been scraped
# Image HeartGold and SoulSilver Promos has been scraped
# Image Arceus has been scraped
# Image Supreme Victors has been scraped
# Image Rising Rivals has been scraped
# Image POP Series 9 has been scraped
# Image Platinum Base Set has been scraped
# Image POP Series 8 has been scraped
# Image Stormfront has been scraped
# Image Legends Awakened has been scraped
# Image Majestic Dawn has been scraped
# Image POP Series 7 has been scraped
# Image Great Encounters has been scraped
# Image Secret Wonders has been scraped
# Image POP Series 6 has been scraped
# Image Trainer Kit – Manaphy & Lucario_0 has been scraped
# Image Trainer Kit – Manaphy & Lucario_1 has been scraped
# Image Mysterious Treasures has been scraped
# Image Diamond & Pearl has been scraped
# Image Diamond & Pearl Promos has been scraped
# Image POP Series 5 has been scraped
# Image Power Keepers has been scraped
# Image Dragon Frontiers has been scraped
# Image Crystal Guardians has been scraped
# Image POP Series 4 has been scraped
# Image Holon Phantoms has been scraped
# Image POP Series 3 has been scraped
# Image EX Trainer Kit 2 - Plusle & Minun_0 has been scraped
# Image EX Trainer Kit 2 - Plusle & Minun_1 has been scraped
# Image Legend Maker has been scraped
# Image Delta Species has been scraped
# Image Unseen Forces has been scraped
# Image POP Series 2 has been scraped
# Image Emerald has been scraped
# Image Deoxys has been scraped
# Image Team Rocket Returns has been scraped
# Image POP Series 1 has been scraped
# Image Fire Red and Leaf Green has been scraped
# Image Hidden Legends has been scraped
# Image EX Trainer Kit - Latias & Latios_0 has been scraped
# Image EX Trainer Kit - Latias & Latios_1 has been scraped
# Image Team Magma vs Team Aqua has been scraped
# Image Dragon has been scraped
# Image Sandstorm has been scraped
# Image Ruby and Sapphire has been scraped
# Image Skyridge has been scraped
# Image Nintendo Black Star Promos has been scraped
# Image Aquapolis has been scraped
# Image Expedition has been scraped
# Image Legendary Collection has been scraped
# Image Neo Destiny has been scraped
# Image Neo Revelation has been scraped
# Image Southern Islands has been scraped
# Image Neo Discovery has been scraped
# Image Neo Genesis has been scraped
# Image Gym Challenge has been scraped
# Image Gym Heroes has been scraped
# Image Team Rocket has been scraped
# Image Base Set 2 has been scraped
# Image Fossil has been scraped
# Image Wizards Black Star Promos has been scraped
# Image Jungle has been scraped
# Image McDonald’s 2022 has been scraped
# Image McDonald’s 2021 has been scraped
# Image McDonald’s 2019 has been scraped
# Image McDonald’s 2018 has been scraped
# Image McDonald’s 2017 has been scraped
# Image McDonald’s 2016 has been scraped
# Image McDonald’s 2015 has been scraped
# Image McDonald’s 2014 has been scraped
# Image McDonald’s 2013 has been scraped
# Image McDonald’s 2012 has been scraped
# Image McDonald’s 2011 has been scraped

# %% [markdown]
# ## Optical Character Recognition

# %%
#Importing libraries
import cv2
import pytesseract
import matplotlib.pyplot as plt

# %%
#Loading image using OpenCV

img = cv2.imread('../raw_data/PokemonCards/white_background/IMG_1487.jpeg')

#Converting to text
text = pytesseract.image_to_string(img)
 
print(text)
# Out:
# 2 Se
#
# ” Po =a “ ‘
# ee pat oe — ee —
#
# NO. 647 Colt Pokémon HI. 4'7" WT. 100.9 Ibs, , |
#
# p/ Creatures / GAME FREAK
#
# ©2022 Pokémon / Nintend
# : am

# %%
plt.imshow(img)
