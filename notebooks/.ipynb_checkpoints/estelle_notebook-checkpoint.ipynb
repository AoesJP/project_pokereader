# %% [markdown]
# # This is Estelle's notebook

# %% [markdown]
# ## Web scrapping to get the series symbol and names

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
import cv2
# import pytesseract

import requests
from bs4 import BeautifulSoup
import httpx

# %%
from PIL import Image
from io import BytesIO

# %%
from pokedex.utils import create_dataset

# %%
url = 'https://cardmavin.com/pokemon/pokemon-card-set-symbols'

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
items = soup.find_all('tr')

# %%
dicty_full = {'name': [], 'link': []}

for item in items:
    if item.find('td', class_='column-3'):
        name = item.find('td', class_='column-1').find('a').text
        links = item.find('td', class_='column-3').find_all("img")
        
        if len(links) > 1:
            for i, link in enumerate(links):
                dicty_full['name'].append( f"{name}_{i}" )
                dicty_full['link'].append( link.attrs["data-src"] )
        elif len(links) == 1:
            dicty_full['name'].append( f"{name}" )
            dicty_full['link'].append( item.find('td', class_='column-3').find("img").attrs["data-src"] )

# %%
for i, thing in enumerate(dicty_full['name']):
    with open(f"../raw_data/SetSymbols/{dicty_full['name'][i]}.png", "wb") as file:
        image = httpx.get(dicty_full["link"][i])
        # Save the image binary data into the file
        file.write(image.content)
        print(f"Image {dicty_full['name'][i]} has been scraped")

print("Image saving is done")
# Out:
# Image Scarlet & Violet 151 has been scraped
# Image Obsidian Flames has been scraped
# Image Paldea Evolved has been scraped
# Image Scarlet & Violet has been scraped
# Image Crown Zenith has been scraped
# Image Silver Tempest has been scraped
# Image Lost Origin has been scraped
# Image Pokemon GO has been scraped
# Image Astral Radiance has been scraped
# Image Brilliant Stars has been scraped
# Image Fusion Strike has been scraped
# Image Celebrations has been scraped
# Image Celebrations Classic Collection has been scraped
# Image Evolving Skies has been scraped
# Image Chilling Reign has been scraped
# Image Battle Styles has been scraped
# Image Shining Fates has been scraped
# Image Vivid Voltage has been scraped
# Image Champion's Path has been scraped
# Image Darkness Ablaze has been scraped
# Image Rebel Clash has been scraped
# Image Sword & Shield has been scraped
# Image Cosmic Eclipse has been scraped
# Image Hidden Fates has been scraped
# Image Unified Minds has been scraped
# Image Unbroken Bonds has been scraped
# Image Detective Pikachu has been scraped
# Image Team Up has been scraped
# Image Lost Thunder has been scraped
# Image Dragon Majesty has been scraped
# Image Celestial Storm has been scraped
# Image Forbidden Light has been scraped
# Image Ultra Prism has been scraped
# Image Crimson Invasion has been scraped
# Image Shining Legends has been scraped
# Image Burning Shadows has been scraped
# Image Guardians Rising has been scraped
# Image Trainer Kit – Lycanroc & Alolan Raichu_0 has been scraped
# Image Trainer Kit – Lycanroc & Alolan Raichu_1 has been scraped
# Image Sun & Moon has been scraped
# Image Sun & Moon Promos has been scraped
# Image Evolutions has been scraped
# Image Steam Siege has been scraped
# Image Fates Collide has been scraped
# Image Trainer Kit – Pikachu Libre & Suicune_0 has been scraped
# Image Trainer Kit – Pikachu Libre & Suicune_1 has been scraped
# Image Generations has been scraped
# Image BREAKpoint has been scraped
# Image BREAKthrough has been scraped
# Image Ancient Origins has been scraped
# Image Roaring Skies has been scraped
# Image Trainer Kit – Latias & Latios_0 has been scraped
# Image Trainer Kit – Latias & Latios_1 has been scraped
# Image Double Crisis has been scraped
# Image Primal Clash has been scraped
# Image Trainer Kit – Bisharp & Wigglytuff_0 has been scraped
# Image Trainer Kit – Bisharp & Wigglytuff_1 has been scraped
# Image Phantom Forces has been scraped
# Image Furious Fists has been scraped
# Image Trainer Kit – Sylveon & Noivern_0 has been scraped
# Image Trainer Kit – Sylveon & Noivern_1 has been scraped
# Image Flashfire has been scraped
# Image XY has been scraped
# Image Kalos Starter Set has been scraped
# Image XY - Promos has been scraped
# Image Legendary Treasures has been scraped
# Image Plasma Blast has been scraped
# Image Plasma Freeze has been scraped
# Image Plasma Storm has been scraped
# Image Boundaries Crossed has been scraped
# Image Dragon Vault has been scraped
# Image Dragons Exalted has been scraped
# Image Dark Explorers has been scraped
# Image Next Destinies has been scraped
# Image Noble Victories has been scraped
# Image Trainer Kit – Excadrill & Zoroark_0 has been scraped
# Image Trainer Kit – Excadrill & Zoroark_1 has been scraped
# Image Emerging Powers has been scraped
# Image Black and White Base Set has been scraped
# Image Call of Legends has been scraped
# Image Triumphant has been scraped
# Image Undaunted has been scraped
# Image Unleashed has been scraped
# Image Trainer Kit – Gyarados & Raichu_0 has been scraped
# Image Trainer Kit – Gyarados & Raichu_1 has been scraped
# Image HeartGold and SoulSilver has been scraped
# Image HeartGold and SoulSilver Promos has been scraped
# Image Arceus has been scraped
# Image Supreme Victors has been scraped
# Image Rising Rivals has been scraped
# Image POP Series 9 has been scraped
# Image Platinum Base Set has been scraped
# Image POP Series 8 has been scraped
# Image Stormfront has been scraped
# Image Legends Awakened has been scraped
# Image Majestic Dawn has been scraped
# Image POP Series 7 has been scraped
# Image Great Encounters has been scraped
# Image Secret Wonders has been scraped
# Image POP Series 6 has been scraped
# Image Trainer Kit – Manaphy & Lucario_0 has been scraped
# Image Trainer Kit – Manaphy & Lucario_1 has been scraped
# Image Mysterious Treasures has been scraped
# Image Diamond & Pearl has been scraped
# Image Diamond & Pearl Promos has been scraped
# Image POP Series 5 has been scraped
# Image Power Keepers has been scraped
# Image Dragon Frontiers has been scraped
# Image Crystal Guardians has been scraped
# Image POP Series 4 has been scraped
# Image Holon Phantoms has been scraped
# Image POP Series 3 has been scraped
# Image EX Trainer Kit 2 - Plusle & Minun_0 has been scraped
# Image EX Trainer Kit 2 - Plusle & Minun_1 has been scraped
# Image Legend Maker has been scraped
# Image Delta Species has been scraped
# Image Unseen Forces has been scraped
# Image POP Series 2 has been scraped
# Image Emerald has been scraped
# Image Deoxys has been scraped
# Image Team Rocket Returns has been scraped
# Image POP Series 1 has been scraped
# Image Fire Red and Leaf Green has been scraped
# Image Hidden Legends has been scraped
# Image EX Trainer Kit - Latias & Latios_0 has been scraped
# Image EX Trainer Kit - Latias & Latios_1 has been scraped
# Image Team Magma vs Team Aqua has been scraped
# Image Dragon has been scraped
# Image Sandstorm has been scraped
# Image Ruby and Sapphire has been scraped
# Image Skyridge has been scraped
# Image Nintendo Black Star Promos has been scraped
# Image Aquapolis has been scraped
# Image Expedition has been scraped
# Image Legendary Collection has been scraped
# Image Neo Destiny has been scraped
# Image Neo Revelation has been scraped
# Image Southern Islands has been scraped
# Image Neo Discovery has been scraped
# Image Neo Genesis has been scraped
# Image Gym Challenge has been scraped
# Image Gym Heroes has been scraped
# Image Team Rocket has been scraped
# Image Base Set 2 has been scraped
# Image Fossil has been scraped
# Image Wizards Black Star Promos has been scraped
# Image Jungle has been scraped
# Image McDonald’s 2022 has been scraped
# Image McDonald’s 2021 has been scraped
# Image McDonald’s 2019 has been scraped
# Image McDonald’s 2018 has been scraped
# Image McDonald’s 2017 has been scraped
# Image McDonald’s 2016 has been scraped
# Image McDonald’s 2015 has been scraped
# Image McDonald’s 2014 has been scraped
# Image McDonald’s 2013 has been scraped
# Image McDonald’s 2012 has been scraped
# Image McDonald’s 2011 has been scraped
# Image saving is done

# %% [markdown]
# ## Optical Character Recognition

# %%
#Loading image using OpenCV

img = cv2.imread('../raw_data/PokemonCards/white_background/IMG_1487.jpeg')

#Converting to text
text = pytesseract.image_to_string(img)
 
print(text)

# %%
plt.imshow(img)

# %% [markdown]
# ## Make dataset

# %%
s_id = 'dv1'
p_id = '1'

url = f'https://api.pokemontcg.io/v2/cards/{s_id}-{p_id}'
response = requests.get(url).json()
image_url = response['data']['images']['large']
# Send a GET request to the image URL
response_card = requests.get(image_url)
# Check if the request was successful
if response_card.status_code == 200:
    # Open the image using PIL
    image = Image.open(BytesIO(response_card.content))

    # Save the image to a file
    # image.save("../raw_data/pokemon_card.png")
    # print("Image saved successfully!")
else:
    print(f"Failed to retrieve image. HTTP Status code: {response_card.status_code}")

# %%
grayImage = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)

# %%
grayImage

# %%
plt.imshow(grayImage, cmap='gray')

# %%
width, height = image.size

# %%
bottomleft = image.crop((width*0.75, height*0.93, width, height))
bottomright = image.crop((0, height*0.93, width*0.25, height))

# %%
bottomleft.size
# Out:
# (184, 72)

# %%
bottomright.size
# Out:
# (184, 72)

# %%
s_id = 'xy1'

for i in range(1,21):
    p_id = str(i) #'2'

    url = f'https://api.pokemontcg.io/v2/cards/{s_id}-{p_id}'
    response = requests.get(url).json()
    image_url = response['data']['images']['large']

    # Send a GET request to the image URL
    response_card = requests.get(image_url)

    # Check if the request was successful
    if response_card.status_code == 200:
        # Open the image using PIL
        image = Image.open(BytesIO(response_card.content))
    
        # Save the image to a file
        # image.save("../raw_data/pokemon_card.png")
        # print("Image saved successfully!")
    else:
        print(f"Failed to retrieve image. HTTP Status code: {response_card.status_code}")

# %%
setinfo = np.array(  
    [['dv1', '21', 'Dragon Vault', 'right'],  
     ['swsh9', '186', 'Brilliant Stars', 'left'],  
     ['swsh45', '73', 'Shining Fates', 'left'],  
     ['swsh6', '233', 'Chilling Reign', 'left'],  
     ['swsh12pt5', '160', 'Crown Zenith', 'left'],  
     ['xy1', '146', 'XY', 'right'],
     ['xy2', '110', 'Flashfire', 'right'],
     ['xy3', '114', 'Furious Fists', 'right'], 
     ['g1', '117', 'Generations', 'right'],
     ['xy4', '124', 'Phantom Forces', 'right'],
     ['xy6', '112', 'Roaring Skies', 'right'],
     ['xy7', '100', 'Ancient Origins', 'right'],
     ['dp1', '130', 'Diamond & Pearl', 'right'],
     ['dp2', '124', 'Mysterious Treasures', 'right'],
     ['sm4', '126', 'Crimson Invasion', 'left'],  
     ['swsh10', '216', 'Astral Radiance', 'left'],
     ['sv4', '266', 'Paradox Rift', 'left'],
     ['sv3pt5', '207', '151', 'left'],
     ['sv3', '230', 'Obsidian Flames', 'left'],  
     ['sv2', '279', 'Paldea Evolved', 'left']])

# %%
setinfo.shape
# Out:
# (20, 4)

# %%
dataset_df = pd.DataFrame(columns=['corner', 'position', 'set_id', 'set_name'], index=[0])
k = 0
for j in range(setinfo.shape[0]):
    s_id = setinfo[j,0]
    print(f'On-going set: {s_id}')
    
    for i in range(1,int(setinfo[j,1])+1):
        url = f'https://api.pokemontcg.io/v2/cards/{s_id}-{str(i)}'
        response = requests.get(url).json()
        image_url = response['data']['images']['large']
    
        # Send a GET request to the image URL
        response_card = requests.get(image_url)
    
        # Check if the request was successful
        if response_card.status_code == 200:
            # Open the image using PIL
            image = Image.open(BytesIO(response_card.content))
            width, height = image.size
        
            bottomleft = image.crop((width*0.75, height*0.93, width, height))
            bottomright = image.crop((0, height*0.93, width*0.25, height))

            graybottomleft = cv2.cvtColor(np.array(bottomleft), cv2.COLOR_BGR2GRAY)
            graybottomright = cv2.cvtColor(np.array(bottomright), cv2.COLOR_BGR2GRAY)

            # location of cropped image in dataframe, careful i starts at 1
            if setinfo[j,3] == 'left':
                dataset_df.loc[k] = [graybottomleft, setinfo[j,3], setinfo[j,0], setinfo[j,2]]
                k+=1
                dataset_df.loc[k] = [graybottomright, 'right', 'no', 'no']
                k+=1
            elif setinfo[j,3] == 'right':
                dataset_df.loc[k] = [graybottomleft, 'left', 'no', 'no']
                k+=1
                dataset_df.loc[k] = [graybottomright, setinfo[j,3], setinfo[j,0], setinfo[j,2]]
                k+=1
        else:
            print(f"Failed to retrieve image. HTTP Status code: {response_card.status_code}")
# Out:
# On-going set: dv1
# On-going set: swsh9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       7 for i in range(1,int(setinfo[j,1])+1):
#       8     url = f'https://api.pokemontcg.io/v2/cards/{s_id}-{str(i)}'
# ----> 9     response = requests.get(url).json()
#      10     image_url = response['data']['images']['large']
#      12     # Send a GET request to the image URL
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
dataset_df
# Out:
#                                                corner position set_id  \
# 0   [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 1   [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 2   [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 3   [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 4   [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 5   [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 6   [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 7   [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 8   [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 9   [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 10  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 11  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 12  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 13  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 14  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 15  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 16  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 17  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 18  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 19  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 20  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 21  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 22  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 23  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 24  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 25  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 26  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 27  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 28  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 29  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 30  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 31  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 32  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 33  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 34  [[129, 129, 129, 129, 129, 129, 129, 129, 129,...     left     no
# 35  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 36  [[129, 129, 129, 129, 129, 129, 129, 129, 129,...     left     no
# 37  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 38  [[129, 129, 129, 129, 129, 129, 129, 129, 129,...     left     no
# 39  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 40  [[85, 80, 80, 80, 80, 79, 79, 79, 79, 68, 68, ...     left     no
# 41  [[190, 190, 190, 190, 190, 190, 190, 190, 190,...    right    dv1
# 42  [[167, 103, 103, 175, 175, 74, 14, 74, 74, 131...     left  swsh9
# 43  [[191, 191, 191, 191, 191, 191, 191, 191, 191,...    right     no
# 44  [[171, 172, 172, 142, 82, 7, 61, 115, 170, 172...     left  swsh9
# 45  [[191, 191, 191, 191, 191, 191, 191, 191, 191,...    right     no
# 46  [[163, 167, 169, 167, 169, 165, 165, 163, 163,...     left  swsh9
# 47  [[191, 191, 191, 191, 191, 191, 191, 191, 191,...    right     no
# 48  [[163, 167, 169, 167, 169, 165, 165, 163, 163,...     left  swsh9
# 49  [[191, 191, 191, 191, 191, 191, 191, 191, 191,...    right     no
# 50  [[163, 167, 169, 167, 169, 165, 165, 163, 163,...     left  swsh9
# 51  [[191, 191, 191, 191, 191, 191, 191, 191, 191,...    right     no
# 52  [[163, 167, 169, 167, 169, 165, 165, 163, 163,...     left  swsh9
# 53  [[191, 191, 191, 191, 191, 191, 191, 191, 191,...    right     no
#
#            set_name
# 0                no
# 1      Dragon Vault
# 2                no
# 3      Dragon Vault
# 4                no
# 5      Dragon Vault
# 6                no
# 7      Dragon Vault
# 8                no
# 9      Dragon Vault
# 10               no
# 11     Dragon Vault
# 12               no
# 13     Dragon Vault
# 14               no
# 15     Dragon Vault
# 16               no
# 17     Dragon Vault
# 18               no
# 19     Dragon Vault
# 20               no
# 21     Dragon Vault
# 22               no
# 23     Dragon Vault
# 24               no
# 25     Dragon Vault
# 26               no
# 27     Dragon Vault
# 28               no
# 29     Dragon Vault
# 30               no
# 31     Dragon Vault
# 32               no
# 33     Dragon Vault
# 34               no
# 35     Dragon Vault
# 36               no
# 37     Dragon Vault
# 38               no
# 39     Dragon Vault
# 40               no
# 41     Dragon Vault
# 42  Brilliant Stars
# 43               no
# 44  Brilliant Stars
# 45               no
# 46  Brilliant Stars
# 47               no
# 48  Brilliant Stars
# 49               no
# 50  Brilliant Stars
# 51               no
# 52  Brilliant Stars
# 53               no

# %%
dataset_df.to_json('../raw_data/dict_dataset.json')

# %%
df=pd.read_json('../raw_data/dict_dataset.json')

# %%
df['corner']=[np.array(v) for v in df['corner']]

# %%
type(df.loc[0,'corner'])
# Out:
# numpy.ndarray

# %%
plt.imshow(dataset_df.loc[1,'corner'])

# %%
df = create_dataset()
# Out:
# On-going set: dv1
# On-going set: swsh9
# On-going set: swsh45
# On-going set: swsh6
# On-going set: swsh12pt5
# On-going set: xy1
# On-going set: xy2
# Failed to retrieve image. HTTP Status code: 404
# On-going set: xy3
# Failed to retrieve image. HTTP Status code: 404
# On-going set: g1
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# On-going set: xy4
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# On-going set: xy6
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# On-going set: xy7
# On-going set: dp1
# On-going set: dp2
# On-going set: sm4
# Failed to retrieve image. HTTP Status code: 404
# Failed to retrieve image. HTTP Status code: 404
# On-going set: swsh10
# On-going set: sv4
# On-going set: sv3pt5
# On-going set: sv3
# On-going set: sv2

# %%
df.to_json('../raw_data/dict_dataset_full.json')

# %%
df.tail()
# Out:
#                                                  corner position  set_id  \
# 4775  [[154, 154, 154, 154, 154, 154, 154, 154, 154,...    right      no
# 4776  [[150, 149, 161, 161, 161, 166, 166, 166, 166,...     left  sv3pt5
# 4777  [[154, 154, 154, 154, 154, 154, 154, 154, 154,...    right      no
# 4778  [[86, 113, 113, 113, 73, 34, 113, 113, 113, 11...     left  sv3pt5
# 4779  [[154, 154, 154, 154, 154, 154, 154, 154, 154,...    right      no
#
#      set_name
# 4775       no
# 4776      151
# 4777       no
# 4778      151
# 4779       no

# %%
url = 'https://api.pokemontcg.io/v2/cards/swsh9-1'
response = requests.get(url)

# %%
response
# Out:
# <Response [429]>
