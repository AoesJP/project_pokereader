# %%
#working with images
import cv2
from PIL import Image
from io import BytesIO

#others
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import os 
import random
import random

#API
import requests

import tensorflow as tf
#import tensorflow_datasets as tfds

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import layers, optimizers, callbacks

from sklearn.pipeline import make_pipeline

# %%
image_files = ['IMG_1487','IMG_1490','IMG_1493','IMG_1496','IMG_1499','IMG_1502','IMG_1505',
'IMG_1488','IMG_1491','IMG_1494','IMG_1497','IMG_1500','IMG_1503','IMG_1506',
'IMG_1489','IMG_1492','IMG_1495','IMG_1498','IMG_1501','IMG_1504']

# %%
image_name = 'IMG_1487.png'
image_path = f'/Users/emiliasato/code/AoesJP/project_pokereader/{image_name}'
image_pic = cv2.imread(image_path)
plt.imshow(image_pic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       2 image_path = f'/Users/emiliasato/code/AoesJP/project_pokereader/{image_name}'
#       3 image_pic = cv2.imread(image_path)
# ----> 4 plt.imshow(image_pic)
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/matplotlib/pyplot.py:3476, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3455 @_copy_docstring_and_deprecators(Axes.imshow)
#    3456 def imshow(
#    3457     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3474     **kwargs,
#    3475 ) -> AxesImage:
# -> 3476     __ret = gca().imshow(
#    3477         X,
#    3478         cmap=cmap,
#    3479         norm=norm,
#    3480         aspect=aspect,
#    3481         interpolation=interpolation,
# ...

# %%
# !ls /Users/emiliasato/code/AoesJP/project_pokereader/raw_data/
# Out:
# IMG_1487.png IMG_1491.png IMG_1495.png IMG_1499.png IMG_1503.png
# IMG_1488.png IMG_1492.png IMG_1496.png IMG_1500.png IMG_1504.png
# IMG_1489.png IMG_1493.png IMG_1497.png IMG_1501.png IMG_1505.png
# IMG_1490.png IMG_1494.png IMG_1498.png IMG_1502.png IMG_1506.png

# %%
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (3, 3), 0)
edged = cv2.Canny(blurred, 10, 250)
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
dilate = cv2.dilate(edged, kernel, iterations=2)
contours, _ = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 2
#       1 image = cv2.imread(image_path)
# ----> 2 gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       3 blurred = cv2.GaussianBlur(gray, (3, 3), 0)
#       4 edged = cv2.Canny(blurred, 10, 250)
#
# error: OpenCV(4.9.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
plt.imshow(dilate)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.imshow(dilate)
#       2 plt.show()
#
# NameError: name 'dilate' is not defined

# %%
import requests
#swsh9-81
#dv1-2
s_id = 'dv1'
p_id = '2'
url = f'https://api.pokemontcg.io/v2/cards/{s_id}-{p_id}'
response = requests.get(url).json()
data = response['data']['images']['large']
data
# Out:
# 'https://images.pokemontcg.io/dv1/2_hires.png'

# %%
from PIL import Image
from io import BytesIO

# URL of the image
image_url = data

# Send a GET request to the image URL
response = requests.get(image_url)

# Check if the request was successful
if response.status_code == 200:
    # Open the image using PIL
    image = Image.open(BytesIO(response.content))
    
    # Save the image to a file
    #image.save("pokemon_card.png")
    print("Image saved successfully!")
else:
    print(f"Failed to retrieve image. HTTP Status code: {response.status_code}")
# Out:
# Image saved successfully!

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=734x1024>

# %%
type(image)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
width, height = image.size
width,height
# Out:
# (734, 1024)

# %%
#bottom left corner
bottom_left_coords = (0, height*0.93, width*0.29, height)
bottom_left_coords 
bottom_left = image.crop(bottom_left_coords)
bottom_left
# Out:
# <PIL.Image.Image image mode=RGBA size=213x72>

# %%
#bottom right corner
bottom_right_coords = (width*0.75, height*0.93, width, height)
bottom_right_coords
bottom_right = image.crop(bottom_right_coords)
bottom_right
# Out:
# <PIL.Image.Image image mode=RGBA size=184x72>

# %%
#cv2.cvtColor(bottom_left, cv2.COLOR_RGB2GRAY)
image_array = np.array(bottom_right)

# Convert RGB to BGR
opencv_image = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)

plt.imshow(opencv_image,cmap='gray')
plt.show()

# %%
bottom_right
# Out:
# <PIL.Image.Image image mode=RGBA size=147x72>

# %%
swsh9-81
dv1-2
s_id = 'swsh9'
p_id = '81'

# %%
s_id = 'swsh9'
image_url = []
for p_id in range(1,20):
    url = f'https://api.pokemontcg.io/v2/cards/{s_id}-{p_id}'
    response = requests.get(url).json()
    data = response['data']['images']['large']
    image_url.append(data)
image_url

for individual_url in image_url:
    response = requests.get(individual_url)

    image = Image.open(BytesIO(response.content))
    width, height = image.size
    bottom_left_coords = (0, height*0.93, width*0.29, height)
    bottom_left = image.crop(bottom_left_coords)

# %% [markdown]
# ## Making functions

# %% [markdown]
# ## Trying out augmentation

# %%
def transform_array(image_np):
    # Reshape to (72, 184, 1)
    width = image_np.shape[0]
    height = image_np.shape[1]
    reshaped_image = image_np.reshape((width, height, 1))
    # Expand dimensions to add batch size
    expanded_image = np.expand_dims(reshaped_image, axis=0)
    return expanded_image

# %%
df=pd.read_json('../raw_data/dict_dataset.json')
df['corner']=[np.array(v) for v in df['corner']]
df['corner'] = df['corner'].apply(transform_array)

df.head(5)
# Out:
#                                               corner position set_id  \
# 0  [[[[85], [80], [80], [80], [80], [79], [79], [...     left     no
# 1  [[[[190], [190], [190], [190], [190], [190], [...    right    dv1
# 2  [[[[85], [80], [80], [80], [80], [79], [79], [...     left     no
# 3  [[[[190], [190], [190], [190], [190], [190], [...    right    dv1
# 4  [[[[85], [80], [80], [80], [80], [79], [79], [...     left     no
#
#        set_name
# 0            no
# 1  Dragon Vault
# 2            no
# 3  Dragon Vault
# 4            no

# %%
set_size = pd.DataFrame(df[['set_id']].value_counts())
set_size.reset_index(inplace=True)
set_size['num_of_aug'] = 300-set_size['count']

# %%
set_size
# Out:
#   set_id  count  num_of_aug
# 0     no     27         273
# 1    dv1     21         279
# 2  swsh9      6         294

# %%
def apply_blur(img):
    img = cv2.convertScaleAbs(img)
    kernel_values = [5, 7]
    selected_kernel = random.choice(kernel_values)
    blurred = cv2.GaussianBlur(img, (selected_kernel, selected_kernel), 0)
    width = img.shape[0]
    height = img.shape[1]
    blurred = blurred.reshape((width,height,1))
    return blurred
    
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=7,
    width_shift_range=3,
    height_shift_range=2,
    preprocessing_function=apply_blur
)

image_np_expanded = np.expand_dims(image_np, axis=0)
it = datagen.flow(image_np_expanded, batch_size=1)
augmented_image = next(it)

plt.imshow(augmented_image[0].squeeze(), cmap='gray')  # Use squeeze to remove single-dimensional entries from the shape
plt.show()

# %%
# Custom function to generate augmented images
def generate_augmented_images(image_np, times):
    image_list = []
    for _ in range(times):
        # Create iterator
        it = datagen.flow(image_np, batch_size=1)
        # Generate augmented image
        augmented_image = next(it)[0].astype(np.uint8)
        image_list.append(augmented_image)
    return image_list

# Example: Apply augmentation to each image in the DataFrame 'times' number of times

new_data = {'augmented_corners': []}
for index, row in df.iterrows():
    original_image = row['corner']
    augmented_images = generate_augmented_images(original_image, 5)
    for aug_img in augmented_images:
        new_data['augmented_corners'].append(aug_img)

new_df = pd.DataFrame(new_data)

plt.imshow(new_df['augmented_corners'].iloc[50].squeeze(), cmap='gray')
plt.show()

# %%
def generate_augmented_image_single(image_np):
    it = datagen.flow(image_np, batch_size=1)
    # Generate augmented image
    augmented_image = next(it)[0].astype(np.uint8)
    return augmented_image

# new_data = {'augmented_corners': []}
# for index, row in df.iterrows():
#     original_image = row['corner']
#     augmented_image = generate_augmented_image_single(original_image)
#     new_data['augmented_corners'].append(augmented_image)

# new_df = pd.DataFrame(new_data)

# plt.imshow(new_df['augmented_corners'].iloc[20].squeeze(), cmap='gray')
# plt.show()

# %%
for index, row in set_size.iterrows():
    if row['count'] < 150:
        print(row['set_id'],row['count'],row['num_of_aug'])
# Out:
# no 27 273
# dv1 21 279
# swsh9 6 294

# %%
# new_df = {'augmented_corners': []}
for index, row in set_size.iterrows():
    for i in range(set_size.loc[index, 'num_of_aug']):
        i_rand = np.random.randint(0, high=set_size.loc[index, 'count'])
        image_ = df.loc[i_rand, 'corner']
        augmented_image = generate_augmented_image_single(image_)
        
        new_df = df.iloc[[i_rand]].copy()
        new_df['corner'] = [augmented_image]

        df = pd.concat([df, new_df], axis=0, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[883], line 9
#       6 augmented_image = generate_augmented_image_single(image_)
#       8 new_df = df.iloc[[i_rand]].copy()
# ----> 9 new_df['corner'] = augmented_image
#      11 df = pd.concat([df, new_df], axis=0, ignore_index=True)
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/pandas/core/frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
# ...

# %%
new_df['corner'] = [augmented_image]

# %%
new_df
# Out:
#                                                corner position set_id set_name
# 10  [[[160], [161], [163], [164], [165], [166], [1...     left     no       no

# %%
new_df = pd.DataFrame(new_df)

new_df.shape
new_df.loc[13,'augmented_corners'].shape
# Out:
# (72, 184, 1)

# %%
plt.imshow(new_df.loc[100,'augmented_corners'],cmap='gray')
