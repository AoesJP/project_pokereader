# %%
from pokedex.text_detection import get_pokeid,ocr_preprocessor
from pokedex.utils_dataset import crop_card
from pokedex.augmentation import get_augment_data
from matplotlib import pyplot as plt
from pokedex.edges.deformer import deform_card
import cv2

# %%
path_name_left = '/Users/emiliasato/code/AoesJP/project_pokereader/raw_data/dict_reduceddataset_left.json'
path_name_right = '/Users/emiliasato/code/AoesJP/project_pokereader/raw_data/dict_reduceddataset_right.json'
augmented_df_left = get_augment_data(path_name_left)
augmented_df_right = get_augment_data(path_name_right)

# %%
i = 304
img = augmented_df_left.loc[i, 'corner']
settle = augmented_df_left.loc[i, 'set_id']
plt.imshow(img)
get_pokeid(img,settle)
# Out:
# '118/1599'

# %%
image_path = '../../raw_data/dv1-2_2.jpg'
plt.imshow(image_pic)
img = deform_card(image_path)
plt.imshow(img)
get_pokeid(img,'dv1')
# Out:
# '1'

# %%
img.squeeze().shape
# Out:
# (880, 660, 3)

# %%
ocr_preprocessor(img,'dv1')
# Out:
# <PIL.Image.Image image mode=RGB size=180x66>

# %%
plt.imshow(crop_card(img))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 plt.imshow(crop_card(img))
#
# File ~/.pyenv/versions/3.10.6/envs/project_pokereader/lib/python3.10/site-packages/matplotlib/pyplot.py:3476, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3455 @_copy_docstring_and_deprecators(Axes.imshow)
#    3456 def imshow(
#    3457     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3474     **kwargs,
#    3475 ) -> AxesImage:
# -> 3476     __ret = gca().imshow(
#    3477         X,
#    3478         cmap=cmap,
#    3479         norm=norm,
#    3480         aspect=aspect,
#    3481         interpolation=interpolation,
#    3482         alpha=alpha,
#    3483         vmin=vmin,
#    3484         vmax=vmax,
#    3485         origin=origin,
# ...
