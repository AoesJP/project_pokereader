# %%
import pickle
import base64
from io import BytesIO
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %%
from pokedex.edges import deformer

# %%
img_file_path = "/Users/yuri/Library/CloudStorage/GoogleDrive-teddy8193@gmail.com/My Drive/Share/project_pokereader/Pokemon Cards/white background/IMG_1488.jpeg"

# %%
img_data = Image.open(img_file_path)
deformed_card = deformer.deform_card(img_data)
plt.imshow(deformed_card)

# %%
deformed_card.shape
# Out:
# (2475, 1800, 3)

# %%
deformed_card.dtype
# Out:
# dtype('uint8')

# %%
buf = BytesIO()
plt.imsave(buf, deformed_card, format="png")
encoded_image_bytes = buf.getvalue()
type(encoded_image_bytes)
# Out:
# bytes

# %%
# data = await file.read()
num_byteio = BytesIO(encoded_image_bytes)
with Image.open(num_byteio) as img:
    num_numpy = np.asarray(img, dtype="uint8")
plt.imshow(num_numpy)

# %%
num_numpy.shape
# Out:
# (2475, 1800, 4)
